# %%
import matplotlib.pyplot as plt
import pandas as pd

# Original data from World Bank national accounts data and OECD National Accounts data files
yemen_data = {
    'Year': [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
    'GDP_Per_Capita': [422.21, 426.77, 447.81, 358.17, 267.94, 264.47, 348.23, 399.71, 359.22, 421.82, 518.15, 515.14, 543.96, 583.39, 669.10, 785.45, 867.78, 956.23, 1153.54, 1045.81, 1249.06, 1284.62, 1349.99, 1497.75, 1557.60, 1488.42, 1069.82, 893.72, 701.71, 693.82, 583.88, 603.71, 676.93]
}

# Create a DataFrame from the original data
df = pd.DataFrame(yemen_data)

# Predicted years
predicted_years = [2023, 2024, 2025, 2026, 2027]

# Forecasted GDP per capita data
forecasted_data = results.get_forecast(steps=5).predicted_mean.values

# Create a new dataset with the predicted years
predicted_data = pd.DataFrame({'Year': predicted_years, 'GDP_Per_Capita': forecasted_data})

# Concatenate the original and predicted datasets
combined_data = pd.concat([df, predicted_data])

# Plotting the actual and forecasted data
plt.plot(combined_data['Year'], combined_data['GDP_Per_Capita'], label='Actual and Forecasted GDP per capita', marker='o')

# Adding labels and title
plt.xlabel('Year')
plt.ylabel('GDP per Capita')
plt.title('Actual and Forecasted GDP per Capita for Yemen')

# Add information about the prediction method
plt.annotate('2023-2027,Forecasted using time series analysis', xy=(2023, 700), xytext=(2023, 850),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

# Add source information
plt.text(1990, 1400, 'Data Source1990-2022: World Bank national accounts data', fontsize=8)

plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# C:\Users\akram\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
combined_data
# Out:
#     Year  GDP_Per_Capita
# 0   1990      422.210000
# 1   1991      426.770000
# 2   1992      447.810000
# 3   1993      358.170000
# 4   1994      267.940000
# 5   1995      264.470000
# 6   1996      348.230000
# 7   1997      399.710000
# 8   1998      359.220000
# 9   1999      421.820000
# 10  2000      518.150000
# 11  2001      515.140000
# 12  2002      543.960000
# 13  2003      583.390000
# 14  2004      669.100000
# 15  2005      785.450000
# 16  2006      867.780000
# 17  2007      956.230000
# 18  2008     1153.540000
# 19  2009     1045.810000
# 20  2010     1249.060000
# 21  2011     1284.620000
# 22  2012     1349.990000
# 23  2013     1497.750000
# 24  2014     1557.600000
# 25  2015     1488.420000
# 26  2016     1069.820000
# 27  2017      893.720000
# 28  2018      701.710000
# 29  2019      693.820000
# 30  2020      583.880000
# 31  2021      603.710000
# 32  2022      676.930000
# 0   2023      700.534194
# 1   2024      714.951985
# 2   2025      723.758585
# ...
